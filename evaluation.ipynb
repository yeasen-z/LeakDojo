# %%
from src.utils import load_save_helper

# %%
path = "./exp/fiqa-chroma/bge-large-en-v1_5-Qwen3-14B/mmr-15-bge-reranker-large-10/BAAI-bge-large-en-v1_5/rewr-True_rerank-True_sum-True_wbtq_20251017_145503_bdbd6c.json"

# %%
results = load_save_helper(path)

# %%
results.keys()
# Out:
# dict_keys(['queries', 'rewritten_queries', 'contexts', 'doc_ids', 'sum_contexts', 'prompts', 'answers', 'reasons'])
