# %% [markdown]
# # Black-box Question Generation Pipeline
#
# This notebook generates domain-adapted English questions using predefined templates and entity slots.
# It is designed to be **non-iterative** (one-shot generation) and suitable for testing across different domain descriptions.
#
# Notebook structure:
# 1. Step 1 — Basic setup (templates & domain weights)
# 2. Step 2 — Input database description
# 3. Step 3 — Allocate templates according to domain
# 4. Step 4 — Generate English questions (slot filling)
# 5. Step 5 — Export results

# %% [markdown]
# ## 1. Step 1 — Basic setup (templates & domain weights)

# %%
import os, sys
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from src.prompts import BlackBoxQueryGenerator

# %% [markdown]
# ## 2. Step 2 — Input database description

# %%
# database_desc = {
#     "name": "chatdoctor",
#     "type": "Medical/Clinical",  # 映射英文类别
#     "intro": "Real conversations between patients and doctors from multiple medical dialogue websites, containing a wealth of authentic case records covering disease symptoms, diagnoses, and treatment recommendations."
# }

database_desc = {
    "name": "fiqa",
    "type": "Finance",  # 映射英文类别
    "intro": "a financial sentiment analysis benchmark derived from real-world sources such as StockTwits posts and financial news headlines.it enables models to understand market sentiment and investor opinions in financial contexts."
}

print("Database description:")
for k, v in database_desc.items():
    print(f"{k}: {v}")
# Out:
# Database description:
# name: fiqa
# type: Finance
# intro: a financial sentiment analysis benchmark derived from real-world sources such as StockTwits posts and financial news headlines.it enables models to understand market sentiment and investor opinions in financial contexts.

# %%
bbqg = BlackBoxQueryGenerator(database_desc,model="./Models/Qwen2.5-14B-Instruct", base_url="http://localhost:22999/v1", api_key="EMPTY")

# %%
bbqg.generate()

# %% [markdown]
# ## 3. Step 3 — Allocate templates according to domain

# %%
# 分配模板
allocation = bbqg.allocate_templates(total_questions=500)
print("Template allocation (number of questions per category):")
print(allocation)
# Out:
# Template allocation (number of questions per category):
# {'A': 125, 'B': 125, 'C': 75, 'D': 50, 'E': 75, 'F': 50}

# %% [markdown]
# ## 4. Step 4 — Generate English questions (slot filling)

# %%
# 生成实体池
response = bbqg.create_entity(num_entities=100)

# %%
print(response)
# Out:
# ["StockTwits", "financial news", "market sentiment", "investor opinions", "stock market", "economy", "finance", "trading", "investment", "capital markets", "bull market", "bear market", "NASDAQ", "NYSE", "S&P 500", "Dow Jones", "economic indicators", "financial analysis", "investment strategies", "risk management", "asset allocation", "diversification", "portfolio management", "fundamental analysis", "technical analysis", "valuation", "earnings reports", "financial statements", "profitability", "liquidity", "efficiency", "revenue", "costs", "expenses", "income", "cash flow", "balance sheet", "price-to-earnings ratio", "return on equity", "return on assets", "dividend yield", "interest rates", "inflation", "unemployment rate", "GDP growth", "consumer confidence", "business cycles", "monetary policy", "fiscal policy", "regulatory environment", "taxation", "corporate governance", "mergers and acquisitions", "initial public offerings", "secondary offerings", "private equity", "venture ca
# ...

# %%
entity_pool = ["StockTwits", "financial news", "market sentiment", "investor opinions", "stock market", "economy", "finance", "trading", "investment", "capital markets", "bull market", "bear market", "NASDAQ", "NYSE", "S&P 500", "Dow Jones", "economic indicators", "financial analysis", "investment strategies", "risk management", "asset allocation", "diversification", "portfolio management", "fundamental analysis", "technical analysis", "valuation", "earnings reports", "financial statements", "profitability", "liquidity", "efficiency", "revenue", "costs", "expenses", "income", "cash flow", "balance sheet", "price-to-earnings ratio", "return on equity", "return on assets", "dividend yield", "interest rates", "inflation", "unemployment rate", "GDP growth", "consumer confidence", "business cycles", "monetary policy", "fiscal policy", "regulatory environment", "taxation", "corporate governance", "mergers and acquisitions", "initial public offerings", "secondary offerings", "private equity", "venture capital", "angel investors", "crowdfunding", "cryptocurrency", "blockchain technology", "digital currencies", "stablecoins", "decentralized finance", "smart contracts", "ICO", "STO", "tokenization", "financial technology", "fintech", "robo-advisors", "algorithmic trading", "high-frequency trading", "quantitative trading", "behavioral finance", "emotional intelligence", "psychological pricing", "cognitive biases", "heuristics", "social proof", "herd mentality", "confirmation bias", "anchoring effect", "loss aversion", "prospect theory", "gambling", "lottery", "casino", "casino games", "poker", "blackjack", "roulette", "slot machines", "sports betting", "horse racing", "greyhound racing", "bingo", "bingo halls", "casinos", "online casinos", "mobile casinos", "live dealer casinos", "virtual reality casinos", "augmented reality casinos", "legal gambling", "illegal gambling", "regulated gambling", "unregulated gambling", "problem gambling", "addiction", "compulsive gambling", "binge gambling", "pathological gambling", "gambling disorder", "treatment for gambling disorder", "support groups", "therapy for gambling addiction", "medication for gambling addiction", "self-help resources", "financial recovery from gambling", "credit counseling", "debt consolidation", "bankruptcy", "financial planning", "retirement planning", "estate planning", "insurance", "life insurance", "health insurance", "disability insurance", "long-term care insurance", "property insurance", "liability insurance", "vehicle insurance", "travel insurance", "homeowners insurance", "renters insurance", "pet insurance", "cyber insurance", "identity theft insurance", "fraud protection", "scam prevention", "financial education", "personal finance", "money management", "budgeting", "savings", "investing basics", "retirement savings", "401(k)", "IRA", "Roth IRA", "annuities", "stocks", "bonds", "mutual funds", "exchange-traded funds", "ETFs", "real estate investment trusts", "REITs", "commodities", "gold", "silver", "oil", "natural gas", "agricultural commodities", "soft commodities", "hard commodities", "metals", "minerals", "precious metals", "base metals", "energy commodities", "agricultural products", "livestock", "grains", "crops", "forex", "foreign exchange", "currency trading", "cross-currency pairs", "major currency pairs", "minor currency pairs", "exotic currency pairs", "pip", "spread", "leverage", "margin", "hedging", "arbitrage", "carry trade", "economic calendar", "central banks", "Federal Reserve", "European Central Bank", "Bank of Japan", "People's Bank of China", "Bank of England", "Swiss National Bank", "financial crises", "subprime mortgage crisis", "dot-com bubble", "Great Depression", "Black Monday", "Black Thursday", "Black Friday", "market crashes", "bear markets", "bull markets", "market corrections", "market rallies", "market downturns", "market upturns", "market volatility", "market stability", "market liquidity", "market depth", "market breadth", "market breadth", "market efficiency", "market transparency", "market fairness", "market ethics", "market integrity", "market regulation", "market oversight", "market compliance", "market discipline", "market competition", "market monopoly", "market oligopoly", "market duopoly", "market collusion", "market cartels", "market dumping", "market skimming", "market penetration", "market development", "market expansion", "market contraction", "market saturation", "market penetration pricing", "market skimming pricing", "cost-plus pricing", "value-based pricing", "penetration pricing", "skimming pricing", "psychological pricing", "price discrimination", "price fixing", "price gouging", "price war", "price signaling", "price anchoring", "price elasticity", "price sensitivity", "price resistance", "price responsiveness", "price elasticity of demand", "price elasticity of supply", "price elasticity of income", "price elasticity of cross", "price elasticity of substitution", "price elasticity of complementarity", "price elasticity of necessity", "price elasticity of luxury", "price elasticity of convenience", "price elasticity of habit", "price elasticity of addiction", "price elasticity of brand loyalty", "price elasticity of information", "price elasticity of advertising", "price elasticity of expectations", "price elasticity of seasonality", "price elasticity of geography", "price elasticity of time", "price elasticity of culture", "price elasticity of social norms", "price elasticity of legal constraints", "price elasticity of regulatory requirements", "price elasticity of technological advancements", "price elasticity of innovation", "price elasticity of quality", "price elasticity of service", "price elasticity of after-sales support", "price elasticity of customization", "price elasticity of personalization", "price elasticity of experience", "price elasticity of exclusivity", "price elasticity of scarcity", "price elasticity of perceived value", "price elasticity of perceived risk", "price elasticity of perceived benefit", "price elasticity of perceived cost", "price elasticity of perceived quality", "price elasticity of perceived service", "price elasticity of perceived after-sales support", "price elasticity of perceived customization", "price elasticity of perceived personalization", "price elasticity of perceived experience", "price elasticity of perceived exclusivity", "price elasticity of perceived scarcity", "price elasticity of perceived perceived value", "price elasticity of perceived perceived risk", "price elasticity of perceived perceived benefit", "price elasticity of perceived perceived cost"]
entity_pool = list(set([e.replace('"','') for e in entity_pool]))

# %%
len(entity_pool)
# Out:
# 304

# %%
# Generate English Questions with Multiple Entities

questions_multi = bbqg.fillin_template(allocation, entity_pool, variants_per_template=3)

# 查看前10个示例
print("Sample multi-entity questions:")
for q in questions_multi[:10]:
    print("-", q)
# Out:
# Sample multi-entity questions:
# - Can you give an example of Dow Jones?
# - Can you give an example of portfolio management?
# - Can you give an example of bingo halls?
# - What are the main features of investment?
# - What are the main features of bear markets?
# - What are the main features of Great Depression?
# - What are the main features of natural gas?
# - What are the main features of stocks?
# - What are the main features of retirement savings?
# - What is sports betting?

# %%
questions_multi
# Out:
# ['Can you give an example of Dow Jones?',
#  'Can you give an example of portfolio management?',
#  'Can you give an example of bingo halls?',
#  'What are the main features of investment?',
#  'What are the main features of bear markets?',
#  'What are the main features of Great Depression?',
#  'What are the main features of natural gas?',
#  'What are the main features of stocks?',
#  'What are the main features of retirement savings?',
#  'What is sports betting?',
#  'What is liability insurance?',
#  'What is price elasticity of time?',
#  'What are the main features of European Central Bank?',
#  'What are the main features of slot machines?',
#  'What are the main features of pathological gambling?',
#  'How does mobile casinos differ from personal finance?',
#  'How does bear markets differ from price elasticity of perceived experience?',
#  'How does price elasticity of perceived perceived value differ from loss aversion?',
# ...

# %%
len(questions_multi)
# Out:
# 1500

# %% [markdown]
# ## 5. Step 5 — Export results

# %%
bbqg.save_questions(questions_multi, "generated_questions_bbq_multi.jsonl", limit=500)
# Out:
# Saved 500 questions to generated_questions_bbq_multi.jsonl
